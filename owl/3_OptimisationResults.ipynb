# %%
import pandas as pd
import numpy as np
import scipy.stats as sp
import matplotlib.pyplot as plt
import matplotlib        as mpl
import matplotlib.colors

from netCDF4 import Dataset

# %%
name='optimisation_output.csv'
sol_file_av = pd.read_csv(name, index_col=None, sep=' ', header=0)    
num_sims=sol_file_av.shape[0]

# %%
print (sol_file_av)
# Out:
#           CV      Test                                                Sol
# 0   0.079046  0.637901  [ 5.  5. 16. 44. 12. 14. 28. 21.  8. 10. 35. 3...
# 1   0.093027  0.607710  [12.  4. 28. 45.  6. 15. 22. 22. 12. 11. 30. 2...
# 2   0.063750  0.669979  [24. 14. 46. 27. 18. 31.  9. 33. 37. 36. 10. 2...
# 3   0.069163  0.675214  [ 4. 16. 13. 42. 56. 14. 11. 28.  6. 14. 37. 4...
# 4   0.067995  0.664812  [24. 14. 10. 55. 43.  9. 21. 45. 36. 33. 20. 4...
# ..       ...       ...                                                ...
# 61  0.073215  0.621820  [34 27 45  1 36  7 20 20 22 32 39  1 29 43 14 ...
# 62  0.074649  0.697260  [ 6 15 10 29 39 44 25 51 30 25 27 51 33 41  7 ...
# 63  0.102632  0.717547  [35 23  5 38 19 53 28 30 20 43 30 48 26 49 44 ...
# 64  0.089517  0.672999  [25  2  2 35 51 33 51 41 38 56  8 17 52 41 24 ...
# 65  0.105246  0.711198  [28 26  3  3 26 18 35 20  2 44 48  1 43  5 41 ...
#
# [66 rows x 3 columns]

# %%
plt.figure(figsize=(9,4))
plt.plot(sol_file_av.index,sol_file_av['Test'],'b',marker='o',ms=0.5,lw=0)
plt.plot(sol_file_av.index,sol_file_av['CV'],'k',marker='o',ms=0.5,lw=0)

plt.xlabel('Optimisation evaluations',fontsize=12)

plt.ylabel('Loss Function (F1-score)',fontsize=12)
plt.ylim([0,1])
plt.grid()

plt.show()

# %%
plt.figure(figsize=(9,6))
plt.scatter(sol_file_av['CV'],sol_file_av['Test'],c=range(num_sims),s=5,alpha=1,cmap='RdYlBu_r')

cbar=plt.colorbar(label="Solution Number",shrink=0.75)
cbar.ax.tick_params(labelsize=10)

plt.xlabel("Training Loss",fontsize=12)
plt.ylabel("Test Loss",fontsize=12)
plt.xlim([0,1])
plt.ylim([0,1])

plt.grid()
plt.show()
